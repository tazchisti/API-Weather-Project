# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=15)
lngs = np.random.uniform(low=-180.000, high=180.000, size=15)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 13

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'
units = "metric"
appid =api_key
# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

weather_data = []


for city in cities:
    response = requests.get(query_url + city).json()
#     if response[cod]
    weather_data.append(response)

pprint (weather_data)
# Out:
# [{'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 19.71, 'lon': -155.08},
#   'dt': 1540858320,
#   'id': 5855927,
#   'main': {'humidity': 97,
#            'pressure': 1014,
#            'temp': 20.47,
#            'temp_max': 23.3,
#            'temp_min': 18.4},
#   'name': 'Hilo',
#   'rain': {'1h': 1.27},
#   'sys': {'country': 'US',
#           'id': 818,
#           'message': 0.0037,
#           'sunrise': 1540916438,
#           'sunset': 1540957617,
#           'type': 1},
#   'visibility': 1609,
#   'weather': [{'description': 'heavy intensity rain',
#                'icon': '10n',
#                'id': 502,
#                'main': 'Rain'},
#               {'description': 'mist',
#                'icon': '50n',
#                'id': 701,
#                'main': 'Mist'}],
#   'wind': {'deg': 280, 'speed': 3.6}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -34.53, 'lon': 20.04},
#   'dt': 1540857600,
#   'id': 1015776,
#   'main': {'humidity': 82,
#            'pressure': 1003,
#            'temp': 15,
#            'temp_max': 15,
#            'temp_min': 15},
#   'name': 'Bredasdorp',
#   'sys': {'country': 'ZA',
#           'id': 6591,
#           'message': 0.0045,
#           'sunrise': 1540870829,
#           'sunset': 1540919218,
#           'type': 1},
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 320, 'gust': 19, 'speed': 11.8}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 70.86, 'lon': 29.09},
#   'dt': 1540853400,
#   'id': 780687,
#   'main': {'humidity': 100,
#            'pressure': 1028,
#            'temp': 4,
#            'temp_max': 4,
#            'temp_min': 4},
#   'name': 'Berlevag',
#   'sys': {'country': 'NO',
#           'id': 5307,
#           'message': 0.0034,
#           'sunrise': 1540881169,
#           'sunset': 1540904415,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 220, 'speed': 5.7}},
#  {'base': 'stations',
#   'clouds': {'all': 36},
#   'cod': 200,
#   'coord': {'lat': 10.4, 'lon': 5.47},
#   'dt': 1540859131,
#   'id': 2334008,
#   'main': {'grnd_level': 992.21,
#            'humidity': 94,
#            'pressure': 992.21,
#            'sea_level': 1025.12,
#            'temp': 21.53,
#            'temp_max': 21.53,
#            'temp_min': 21.53},
#   'name': 'Kontagora',
#   'sys': {'country': 'NG',
#           'message': 0.0036,
#           'sunrise': 1540877314,
#           'sunset': 1540919687},
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 11.0002, 'speed': 0.92}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -54.81, 'lon': -68.31},
#   'dt': 1540854060,
#   'id': 3833367,
#   'main': {'humidity': 34,
#            'pressure': 994,
#            'temp': 10,
#            'temp_max': 10,
#            'temp_min': 10},
#   'name': 'Ushuaia',
#   'sys': {'country': 'AR',
#           'id': 4754,
#           'message': 0.004,
#           'sunrise': 1540889331,
#           'sunset': 1540943170,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 320, 'speed': 6.2}},
#  {'base': 'stations',
#   'clouds': {'all': 68},
#   'cod': 200,
#   'coord': {'lat': 62.53, 'lon': 155.8},
#   'dt': 1540859131,
#   'id': 2122493,
#   'main': {'grnd_level': 928.34,
#            'humidity': 85,
#            'pressure': 928.34,
#            'sea_level': 1022.97,
#            'temp': -7.5,
#            'temp_max': -7.5,
#            'temp_min': -7.5},
#   'name': 'Omsukchan',
#   'sys': {'country': 'RU',
#           'message': 0.0031,
#           'sunrise': 1540847012,
#           'sunset': 1540877777},
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 334, 'speed': 3.12}},
#  {'base': 'stations',
#   'clouds': {'all': 80},
#   'cod': 200,
#   'coord': {'lat': -45.87, 'lon': 170.5},
#   'dt': 1540858940,
#   'id': 2191562,
#   'main': {'grnd_level': 977.62,
#            'humidity': 91,
#            'pressure': 977.62,
#            'sea_level': 1017.9,
#            'temp': 7.91,
#            'temp_max': 7.91,
#            'temp_min': 7.91},
#   'name': 'Dunedin',
#   'rain': {'3h': 0.33},
#   'sys': {'country': 'NZ',
#           'message': 0.0035,
#           'sunrise': 1540833527,
#           'sunset': 1540884322},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 222.5, 'speed': 5.47}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 64.42, 'lon': -173.23},
#   'dt': 1540855800,
#   'id': 4031574,
#   'main': {'humidity': 86,
#            'pressure': 1005,
#            'temp': 1,
#            'temp_max': 1,
#            'temp_min': 1},
#   'name': 'Provideniya',
#   'sys': {'country': 'RU',
#           'id': 7239,
#           'message': 0.004,
#           'sunrise': 1540926745,
#           'sunset': 1540955969,
#           'type': 1},
#   'visibility': 8000,
#   'weather': [{'description': 'light shower snow',
#                'icon': '13d',
#                'id': 620,
#                'main': 'Snow'}],
#   'wind': {'deg': 80, 'speed': 3}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 60.72, 'lon': -46.03},
#   'dt': 1540857000,
#   'id': 3420846,
#   'main': {'humidity': 48,
#            'pressure': 1003,
#            'temp': -7,
#            'temp_max': -7,
#            'temp_min': -7},
#   'name': 'Qaqortoq',
#   'sys': {'country': 'GL',
#           'id': 4791,
#           'message': 0.0035,
#           'sunrise': 1540895053,
#           'sunset': 1540926615,
#           'type': 1},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 80, 'speed': 3.1}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -46.43, 'lon': -67.52},
#   'dt': 1540859132,
#   'id': 3863379,
#   'main': {'grnd_level': 998.54,
#            'humidity': 68,
#            'pressure': 998.54,
#            'sea_level': 1019.85,
#            'temp': 10.33,
#            'temp_max': 10.33,
#            'temp_min': 10.33},
#   'name': 'Mar del Plata',
#   'sys': {'country': 'AR',
#           'message': 0.0037,
#           'sunrise': 1540890515,
#           'sunset': 1540941581},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 48.5002, 'speed': 5.57}},
#  {'base': 'stations',
#   'clouds': {'all': 44},
#   'cod': 200,
#   'coord': {'lat': -30.17, 'lon': -50.22},
#   'dt': 1540859132,
#   'id': 3466165,
#   'main': {'grnd_level': 1018.4,
#            'humidity': 77,
#            'pressure': 1018.4,
#            'sea_level': 1028.6,
#            'temp': 18.93,
#            'temp_max': 18.93,
#            'temp_min': 18.93},
#   'name': 'Cidreira',
#   'sys': {'country': 'BR',
#           'message': 0.0072,
#           'sunrise': 1540888057,
#           'sunset': 1540935708},
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 51.5002, 'speed': 8.22}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 39.45, 'lon': 22.34},
#   'dt': 1540857000,
#   'id': 262462,
#   'main': {'humidity': 93,
#            'pressure': 1020,
#            'temp': 14,
#            'temp_max': 14,
#            'temp_min': 14},
#   'name': 'Saint George',
#   'sys': {'country': 'GR',
#           'id': 5674,
#           'message': 0.0044,
#           'sunrise': 1540875375,
#           'sunset': 1540913505,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 240, 'speed': 2.1}}]

# %%
#print (weather_data[1]["cod"])
cities[0]
#query_url
# Out:
# 'hilo'

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = []
for weather_info in weather_data:
      if(weather_info["cod"]==200):
            weather_dict.append({'City': weather_info['name'], 'Temperature:': weather_info["main"]['temp'], 
                                 'Humidity':weather_info["main"]['humidity'],'Cloudiness': weather_info["clouds"]['all'],
                                'Wind Speed': weather_info["wind"]['speed'], 'Latitude': weather_info["coord"]['lat'],
                                 'Longitude':weather_info["coord"]['lon'], 'Date': weather_info["dt"]})

# %%
weather_df = pd.DataFrame(weather_dict)
weather_df
# Out:
#              City  Cloudiness        Date  Humidity  Latitude  Longitude  \
# 0            Hilo          90  1540858320        97     19.71    -155.08
# 1      Bredasdorp          20  1540857600        82    -34.53      20.04
# 2        Berlevag           0  1540853400       100     70.86      29.09
# 3       Kontagora          36  1540859131        94     10.40       5.47
# 4         Ushuaia          40  1540854060        34    -54.81     -68.31
# 5       Omsukchan          68  1540859131        85     62.53     155.80
# 6         Dunedin          80  1540858940        91    -45.87     170.50
# 7     Provideniya          90  1540855800        86     64.42    -173.23
# 8        Qaqortoq           0  1540857000        48     60.72     -46.03
# 9   Mar del Plata           0  1540859132        68    -46.43     -67.52
# 10       Cidreira          44  1540859132        77    -30.17     -50.22
# 11   Saint George          20  1540857000        93     39.45      22.34
#
#     Temperature:  Wind Speed
# 0          20.47        3.60
# 1          15.00       11.80
# 2           4.00        5.70
# 3          21.53        0.92
# 4          10.00        6.20
# 5          -7.50        3.12
# 6           7.91        5.47
# 7           1.00        3.00
# 8          -7.00        3.10
# 9          10.33        5.57
# 10         18.93        8.22
# 11         14.00        2.10

# %%
weather_df.count()
# Out:
# City            12
# Cloudiness      12
# Date            12
# Humidity        12
# Latitude        12
# Longitude       12
# Temperature:    12
# Wind Speed      12
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Latitude'],weather_df['Temperature:'])
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
